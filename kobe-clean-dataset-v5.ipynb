# %%
########################
# CLEANING UP THE DATA #
########################

import os
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn import neighbors, metrics, grid_search, cross_validation
from sklearn.feature_selection import VarianceThreshold, RFE, SelectKBest, chi2
from sklearn.ensemble import BaggingClassifier, ExtraTreesClassifier, GradientBoostingClassifier, VotingClassifier, RandomForestClassifier, AdaBoostClassifier

pd.set_option('display.max_rows', 162)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 162)

# %matplotlib inline
plt.style.use('ggplot')

# %%
df = pd.read_csv('/Users/joshuagrossman/Desktop/DS-SF-23 Final Project/Kobe/kobe_data_1.csv')

# %%
df.head()
# Out:
#          action_type combined_shot_type  game_event_id   game_id      lat  \
# 0          Jump Shot          Jump Shot             10  20000012  33.9723
# 1          Jump Shot          Jump Shot             12  20000012  34.0443
# 2          Jump Shot          Jump Shot             35  20000012  33.9093
# 3          Jump Shot          Jump Shot             43  20000012  33.8693
# 4  Driving Dunk Shot               Dunk            155  20000012  34.0443
#
#    loc_x  loc_y       lon  minutes_remaining  period  playoffs   season  \
# 0    167     72 -118.1028                 10       1         0  2000-01
# 1   -157      0 -118.4268                 10       1         0  2000-01
# 2   -101    135 -118.3708                  7       1         0  2000-01
# 3    138    175 -118.1318                  6       1         0  2000-01
# 4      0      0 -118.2698                  6       2         0  2000-01
#
#    seconds_remaining  shot_distance  shot_made_flag       shot_type  \
# 0                 27             18             NaN  2PT Field Goal
# 1                 22             15             0.0  2PT Field Goal
# 2                 45             16             1.0  2PT Field Goal
# 3                 52             22             0.0  2PT Field Goal
# 4                 19              0             1.0  2PT Field Goal
#
#           shot_zone_area  shot_zone_basic  shot_zone_range     team_id  \
# 0          Right Side(R)        Mid-Range        16-24 ft.  1610612747
# 1           Left Side(L)        Mid-Range         8-16 ft.  1610612747
# 2   Left Side Center(LC)        Mid-Range        16-24 ft.  1610612747
# 3  Right Side Center(RC)        Mid-Range        16-24 ft.  1610612747
# 4              Center(C)  Restricted Area  Less Than 8 ft.  1610612747
#
#             team_name   game_date    matchup opponent  shot_id
# 0  Los Angeles Lakers  2000-10-31  LAL @ POR      POR        1
# 1  Los Angeles Lakers  2000-10-31  LAL @ POR      POR        2
# 2  Los Angeles Lakers  2000-10-31  LAL @ POR      POR        3
# 3  Los Angeles Lakers  2000-10-31  LAL @ POR      POR        4
# 4  Los Angeles Lakers  2000-10-31  LAL @ POR      POR        5

# %%
df.set_index('shot_id', inplace=True)
df["action_type"] = df["action_type"].astype('object')
df["combined_shot_type"] = df["combined_shot_type"].astype('category')
df["game_event_id"] = df["game_event_id"].astype('category')
df["game_id"] = df["game_id"].astype('category')
df["period"] = df["period"].astype('object')
df["playoffs"] = df["playoffs"].astype('category')
df["season"] = df["season"].astype('category')
df["shot_made_flag"] = df["shot_made_flag"].astype('category')
df["shot_type"] = df["shot_type"].astype('category')
df["team_id"] = df["team_id"].astype('category')

# %%
df.shape
# Out:
# (30697, 24)

# %%
df.dtypes
# Out:
# action_type             object
# combined_shot_type    category
# game_event_id         category
# game_id               category
# lat                    float64
# loc_x                    int64
# loc_y                    int64
# lon                    float64
# minutes_remaining        int64
# period                  object
# playoffs              category
# season                category
# seconds_remaining        int64
# shot_distance            int64
# shot_made_flag        category
# shot_type             category
# shot_zone_area          object
# shot_zone_basic         object
# shot_zone_range         object
# team_id               category
# team_name               object
# game_date               object
# matchup                 object
# opponent                object
# dtype: object

# %%
#Create a clean data set
data_cl = df.copy() # create a copy of data frame

target = data_cl['shot_made_flag'].copy()

# %%
data_cl.shape
# Out:
# (30697, 24)

# %%
unknown_mask = df['shot_made_flag'].isnull()

# %%
# Remove some columns
data_cl.drop('team_id', axis=1, inplace=True) # Always one number
data_cl.drop('lat', axis=1, inplace=True) # Correlated with loc_x
data_cl.drop('lon', axis=1, inplace=True) # Correlated with loc_y
data_cl.drop('game_id', axis=1, inplace=True) # Independent
data_cl.drop('game_event_id', axis=1, inplace=True) # Independent
data_cl.drop('team_name', axis=1, inplace=True) # Always LA Lakers
#data_cl.drop('shot_made_flag', axis=1, inplace=True) #need to copy before dropping

# %%
data_cl.dtypes
# Out:
# action_type             object
# combined_shot_type    category
# loc_x                    int64
# loc_y                    int64
# minutes_remaining        int64
# period                  object
# playoffs              category
# season                category
# seconds_remaining        int64
# shot_distance            int64
# shot_made_flag        category
# shot_type             category
# shot_zone_area          object
# shot_zone_basic         object
# shot_zone_range         object
# game_date               object
# matchup                 object
# opponent                object
# dtype: object

# %%
#def detect_outliers(series, whis=1.5):
#   q75, q25 = np.percentile(series, [75 ,25])
#  iqr = q75 - q25
#    return ~((series - series.median()).abs() <= (whis * iqr))

## For now - do not remove anything

# %%
#New Features:

# Remaining time
data_cl['seconds_from_period_end'] = 60 * data_cl['minutes_remaining'] + data_cl['seconds_remaining']
#data_cl['last_5_sec_in_period'] = data_cl['seconds_from_period_end'] < 5

data_cl.drop('minutes_remaining', axis=1, inplace=True)
data_cl.drop('seconds_remaining', axis=1, inplace=True)
#data_cl.drop('seconds_from_period_end', axis=1, inplace=True)

#Add a home vs away column based on matchup
data_cl['home_away'] = np.where(df['matchup'].str.contains("vs."), 'home', 'away')
#Create binary variable for Home/Away games
data_cl.home_away = data_cl.home_away.apply(lambda value: 0 if value == 'away' else 1)
data_cl.drop('matchup', axis=1, inplace=True)

# Game date
data_cl['game_date'] = pd.to_datetime(data_cl['game_date'])
data_cl['game_year'] = data_cl['game_date'].dt.year
data_cl['game_month'] = data_cl['game_date'].dt.month
data_cl.drop('game_date', axis=1, inplace=True)

# Replace 20 least common action types with value 'Other'
rare_action_types = data_cl['action_type'].value_counts().sort_values().index.values[:20]
data_cl.loc[data_cl['action_type'].isin(rare_action_types), 'action_type'] = 'Other'

# %%
#create dummy variables for categorical features
categorial_cols = [
    'action_type', 'combined_shot_type', 'period', 'season', 'shot_type',
    'shot_zone_area', 'shot_zone_basic', 'shot_zone_range', 'game_year',
    'game_month', 'opponent']

for cc in categorial_cols:
    dummies = pd.get_dummies(data_cl[cc])
    dummies = dummies.add_prefix("{}#".format(cc))
    data_cl.drop(cc, axis=1, inplace=True)
    data_cl = data_cl.join(dummies)

# %%
data_cl.shape
# Out:
# (30697, 161)

# %%
data_cl.columns
# Out:
# Index([u'loc_x', u'loc_y', u'playoffs', u'shot_distance', u'shot_made_flag',
#        u'seconds_from_period_end', u'home_away',
#        u'action_type#Alley Oop Dunk Shot', u'action_type#Alley Oop Layup shot',
#        u'action_type#Driving Dunk Shot',
#        ...
#        u'opponent#PHI', u'opponent#PHX', u'opponent#POR', u'opponent#SAC',
#        u'opponent#SAS', u'opponent#SEA', u'opponent#TOR', u'opponent#UTA',
#        u'opponent#VAN', u'opponent#WAS'],
#       dtype='object', length=161)

# %%
data_cl.dtypes
# Out:
# loc_x                                            int64
# loc_y                                            int64
# playoffs                                      category
# shot_distance                                    int64
# shot_made_flag                                category
# seconds_from_period_end                          int64
# home_away                                        int64
# action_type#Alley Oop Dunk Shot                float64
# action_type#Alley Oop Layup shot               float64
# action_type#Driving Dunk Shot                  float64
# action_type#Driving Finger Roll Layup Shot     float64
# action_type#Driving Finger Roll Shot           float64
# action_type#Driving Jump shot                  float64
# action_type#Driving Layup Shot                 float64
# action_type#Driving Reverse Layup Shot         float64
# action_type#Driving Slam Dunk Shot             float64
# action_type#Dunk Shot                          float64
# action_type#Fadeaway Bank shot                 float64
# action_type#Fadeaway Jump Shot                 float64
# action_type#Finger Roll Layup Shot             float64
# action_type#Finger Roll Shot                   float64
# action_type#Floating Jump shot                 float64
# action_type#Follow Up Dunk Shot                float64
# action_type#Hook Shot                          float64
# action_type#Jump Bank Shot                     float64
# action_type#Jump Hook Shot                     float64
# action_type#Jump Shot                          float64
# action_type#Layup Shot                         float64
# action_type#Other                              float64
# action_type#Pullup Jump shot                   float64
# action_type#Putback Layup Shot                 float64
# action_type#Reverse Dunk Shot                  float64
# action_type#Reverse Layup Shot                 float64
# action_type#Reverse Slam Dunk Shot             float64
# action_type#Running Bank shot                  float64
# action_type#Running Dunk Shot                  float64
# action_type#Running Hook Shot                  float64
# action_type#Running Jump Shot                  float64
# action_type#Running Layup Shot                 float64
# action_type#Slam Dunk Shot                     float64
# action_type#Step Back Jump shot                float64
# action_type#Tip Shot                           float64
# action_type#Turnaround Bank shot               float64
# action_type#Turnaround Fadeaway shot           float64
# action_type#Turnaround Jump Shot               float64
# combined_shot_type#Bank Shot                   float64
# combined_shot_type#Dunk                        float64
# combined_shot_type#Hook Shot                   float64
# combined_shot_type#Jump Shot                   float64
# combined_shot_type#Layup                       float64
# combined_shot_type#Tip Shot                    float64
# period#1                                       float64
# period#2                                       float64
# period#3                                       float64
# period#4                                       float64
# period#5                                       float64
# period#6                                       float64
# period#7                                       float64
# season#1996-97                                 float64
# season#1997-98                                 float64
# season#1998-99                                 float64
# season#1999-00                                 float64
# season#2000-01                                 float64
# season#2001-02                                 float64
# season#2002-03                                 float64
# season#2003-04                                 float64
# season#2004-05                                 float64
# season#2005-06                                 float64
# season#2006-07                                 float64
# season#2007-08                                 float64
# season#2008-09                                 float64
# season#2009-10                                 float64
# season#2010-11                                 float64
# season#2011-12                                 float64
# season#2012-13                                 float64
# season#2013-14                                 float64
# season#2014-15                                 float64
# season#2015-16                                 float64
# shot_type#2PT Field Goal                       float64
# shot_type#3PT Field Goal                       float64
# shot_zone_area#Back Court(BC)                  float64
# shot_zone_area#Center(C)                       float64
# shot_zone_area#Left Side Center(LC)            float64
# shot_zone_area#Left Side(L)                    float64
# shot_zone_area#Right Side Center(RC)           float64
# shot_zone_area#Right Side(R)                   float64
# shot_zone_basic#Above the Break 3              float64
# shot_zone_basic#Backcourt                      float64
# shot_zone_basic#In The Paint (Non-RA)          float64
# shot_zone_basic#Left Corner 3                  float64
# shot_zone_basic#Mid-Range                      float64
# shot_zone_basic#Restricted Area                float64
# shot_zone_basic#Right Corner 3                 float64
# shot_zone_range#16-24 ft.                      float64
# shot_zone_range#24+ ft.                        float64
# shot_zone_range#8-16 ft.                       float64
# shot_zone_range#Back Court Shot                float64
# shot_zone_range#Less Than 8 ft.                float64
# game_year#1996                                 float64
# game_year#1997                                 float64
# game_year#1998                                 float64
# game_year#1999                                 float64
# game_year#2000                                 float64
# game_year#2001                                 float64
# game_year#2002                                 float64
# game_year#2003                                 float64
# game_year#2004                                 float64
# game_year#2005                                 float64
# game_year#2006                                 float64
# game_year#2007                                 float64
# game_year#2008                                 float64
# game_year#2009                                 float64
# game_year#2010                                 float64
# game_year#2011                                 float64
# game_year#2012                                 float64
# game_year#2013                                 float64
# game_year#2014                                 float64
# game_year#2015                                 float64
# game_year#2016                                 float64
# game_month#1                                   float64
# game_month#2                                   float64
# game_month#3                                   float64
# game_month#4                                   float64
# game_month#5                                   float64
# game_month#6                                   float64
# game_month#10                                  float64
# game_month#11                                  float64
# game_month#12                                  float64
# opponent#ATL                                   float64
# opponent#BKN                                   float64
# opponent#BOS                                   float64
# opponent#CHA                                   float64
# opponent#CHI                                   float64
# opponent#CLE                                   float64
# opponent#DAL                                   float64
# opponent#DEN                                   float64
# opponent#DET                                   float64
# opponent#GSW                                   float64
# opponent#HOU                                   float64
# opponent#IND                                   float64
# opponent#LAC                                   float64
# opponent#MEM                                   float64
# opponent#MIA                                   float64
# opponent#MIL                                   float64
# opponent#MIN                                   float64
# opponent#NJN                                   float64
# opponent#NOH                                   float64
# opponent#NOP                                   float64
# opponent#NYK                                   float64
# opponent#OKC                                   float64
# opponent#ORL                                   float64
# opponent#PHI                                   float64
# opponent#PHX                                   float64
# opponent#POR                                   float64
# opponent#SAC                                   float64
# opponent#SAS                                   float64
# opponent#SEA                                   float64
# opponent#TOR                                   float64
# opponent#UTA                                   float64
# opponent#VAN                                   float64
# opponent#WAS                                   float64
# dtype: object

# %%
#normalize for any numerical variables needed 
def normalize(X):
    min = X.min()
    max = X.max()
    return (X - min) / (max - min)

data_cl['seconds_from_period_end'] = normalize(data_cl.seconds_from_period_end)
data_cl['shot_distance'] = normalize(data_cl.shot_distance)
data_cl['loc_x'] = normalize(data_cl.loc_x)
data_cl['loc_y'] = normalize(data_cl.loc_y)

# %%
data_cl.shape
# Out:
# (30697, 161)

# %%
unknown_mask = df['shot_made_flag'].isnull()

# %%
# Separate dataset for validation
data_submit = data_cl[unknown_mask]

# Separate dataset for training
X = data_cl[~unknown_mask]
Y = target[~unknown_mask]

# %%
#Variance Threshold
#Find all features with more than 90% variance in values.

threshold = 0.90
vt = VarianceThreshold().fit(X)

# Find feature names
feat_var_threshold = data_cl.columns[vt.variances_ > threshold * (1-threshold)]
feat_var_threshold
# Out:
# Index([u'playoffs', u'shot_made_flag', u'home_away', u'action_type#Jump Shot',
#        u'combined_shot_type#Jump Shot', u'combined_shot_type#Layup',
#        u'period#1', u'period#2', u'period#3', u'period#4',
#        u'shot_type#2PT Field Goal', u'shot_type#3PT Field Goal',
#        u'shot_zone_area#Center(C)', u'shot_zone_area#Left Side Center(LC)',
#        u'shot_zone_area#Left Side(L)', u'shot_zone_area#Right Side Center(RC)',
#        u'shot_zone_area#Right Side(R)', u'shot_zone_basic#Above the Break 3',
#        u'shot_zone_basic#In The Paint (Non-RA)', u'shot_zone_basic#Mid-Range',
#        u'shot_zone_basic#Restricted Area', u'shot_zone_range#16-24 ft.',
#        u'shot_zone_range#24+ ft.', u'shot_zone_range#8-16 ft.',
#        u'shot_zone_range#Less Than 8 ft.', u'game_month#1', u'game_month#2',
#        u'game_month#3', u'game_month#4', u'game_month#11', u'game_month#12'],
#       dtype='object')

# %%
#Top 20 most important features
#According to RandomForestClassifier

model = RandomForestClassifier()
model.fit(X, Y)

feature_imp = pd.DataFrame(model.feature_importances_, index=X.columns, columns=["importance"])
feat_imp_20 = feature_imp.sort_values("importance", ascending=False).head(20).index
feat_imp_20
# Out:
# Index([u'shot_made_flag', u'action_type#Jump Shot', u'seconds_from_period_end',
#        u'loc_y', u'loc_x', u'combined_shot_type#Dunk', u'shot_distance',
#        u'shot_zone_basic#Restricted Area', u'combined_shot_type#Layup',
#        u'action_type#Layup Shot', u'home_away',
#        u'combined_shot_type#Jump Shot', u'action_type#Driving Layup Shot',
#        u'action_type#Slam Dunk Shot', u'shot_zone_area#Center(C)', u'period#1',
#        u'period#3', u'period#2', u'action_type#Running Jump Shot',
#        u'shot_type#3PT Field Goal'],
#       dtype='object')

# %%
feature_imp.sort_values("importance", ascending=False)
# Out:
#                                             importance
# shot_made_flag                                0.781880
# action_type#Jump Shot                         0.025250
# seconds_from_period_end                       0.018068
# loc_y                                         0.012974
# loc_x                                         0.011364
# combined_shot_type#Dunk                       0.008252
# shot_distance                                 0.008249
# shot_zone_basic#Restricted Area               0.006335
# combined_shot_type#Layup                      0.005401
# action_type#Layup Shot                        0.004937
# home_away                                     0.003857
# combined_shot_type#Jump Shot                  0.003767
# action_type#Driving Layup Shot                0.003590
# action_type#Slam Dunk Shot                    0.002607
# shot_zone_area#Center(C)                      0.002451
# period#1                                      0.002431
# period#3                                      0.002232
# period#2                                      0.002089
# action_type#Running Jump Shot                 0.002069
# shot_type#3PT Field Goal                      0.001873
# game_month#1                                  0.001707
# game_month#3                                  0.001694
# period#4                                      0.001666
# shot_zone_range#Less Than 8 ft.               0.001614
# game_month#11                                 0.001551
# shot_type#2PT Field Goal                      0.001540
# opponent#SAS                                  0.001507
# shot_zone_range#24+ ft.                       0.001452
# playoffs                                      0.001449
# game_month#12                                 0.001425
# game_month#2                                  0.001416
# game_month#4                                  0.001344
# opponent#GSW                                  0.001264
# game_year#2008                                0.001192
# opponent#POR                                  0.001189
# opponent#DEN                                  0.001187
# shot_zone_area#Left Side(L)                   0.001164
# action_type#Jump Bank Shot                    0.001158
# action_type#Pullup Jump shot                  0.001156
# opponent#PHX                                  0.001105
# season#2008-09                                0.001085
# shot_zone_basic#In The Paint (Non-RA)         0.001070
# opponent#UTA                                  0.001062
# game_year#2010                                0.001020
# shot_zone_area#Right Side Center(RC)          0.001012
# game_year#2012                                0.001001
# opponent#LAC                                  0.000992
# opponent#MIN                                  0.000985
# opponent#HOU                                  0.000974
# opponent#SAC                                  0.000970
# opponent#PHI                                  0.000963
# game_year#2000                                0.000945
# opponent#MEM                                  0.000937
# season#2000-01                                0.000924
# game_year#2003                                0.000922
# game_year#2006                                0.000918
# game_year#2007                                0.000906
# season#2007-08                                0.000899
# game_year#2009                                0.000889
# opponent#DAL                                  0.000849
# action_type#Fadeaway Jump Shot                0.000847
# season#2011-12                                0.000844
# action_type#Tip Shot                          0.000840
# game_year#2001                                0.000837
# season#2009-10                                0.000831
# season#2012-13                                0.000829
# season#2002-03                                0.000807
# shot_zone_area#Right Side(R)                  0.000797
# game_year#2005                                0.000792
# game_month#5                                  0.000791
# season#2004-05                                0.000783
# season#2001-02                                0.000770
# shot_zone_range#16-24 ft.                     0.000760
# season#2010-11                                0.000758
# opponent#ORL                                  0.000756
# opponent#SEA                                  0.000718
# game_month#6                                  0.000715
# season#2003-04                                0.000709
# season#1999-00                                0.000705
# opponent#IND                                  0.000701
# action_type#Driving Dunk Shot                 0.000697
# opponent#NYK                                  0.000695
# shot_zone_area#Left Side Center(LC)           0.000689
# opponent#DET                                  0.000688
# season#2006-07                                0.000686
# opponent#TOR                                  0.000679
# action_type#Turnaround Jump Shot              0.000679
# season#2005-06                                0.000671
# game_year#2016                                0.000659
# season#2015-16                                0.000652
# game_year#2002                                0.000629
# game_year#2013                                0.000627
# opponent#BOS                                  0.000620
# opponent#NJN                                  0.000616
# season#1998-99                                0.000603
# opponent#WAS                                  0.000602
# shot_zone_basic#Mid-Range                     0.000600
# opponent#MIL                                  0.000592
# opponent#NOH                                  0.000587
# opponent#CLE                                  0.000587
# shot_zone_range#8-16 ft.                      0.000586
# game_year#2004                                0.000564
# game_year#1999                                0.000563
# opponent#CHI                                  0.000553
# game_year#1998                                0.000548
# opponent#CHA                                  0.000540
# action_type#Reverse Layup Shot                0.000539
# game_year#2011                                0.000519
# opponent#MIA                                  0.000507
# season#1997-98                                0.000490
# season#2014-15                                0.000488
# opponent#OKC                                  0.000481
# opponent#ATL                                  0.000466
# action_type#Driving Finger Roll Layup Shot    0.000465
# game_year#2015                                0.000417
# shot_zone_basic#Above the Break 3             0.000401
# game_year#1997                                0.000395
# opponent#NOP                                  0.000385
# action_type#Turnaround Fadeaway shot          0.000316
# action_type#Floating Jump shot                0.000313
# period#5                                      0.000300
# action_type#Driving Reverse Layup Shot        0.000288
# combined_shot_type#Bank Shot                  0.000278
# action_type#Step Back Jump shot               0.000264
# game_year#2014                                0.000257
# game_month#10                                 0.000257
# action_type#Driving Finger Roll Shot          0.000243
# shot_zone_range#Back Court Shot               0.000225
# action_type#Turnaround Bank shot              0.000222
# action_type#Dunk Shot                         0.000210
# action_type#Driving Slam Dunk Shot            0.000208
# action_type#Hook Shot                         0.000192
# shot_zone_area#Back Court(BC)                 0.000179
# opponent#VAN                                  0.000176
# season#1996-97                                0.000171
# game_year#1996                                0.000165
# action_type#Alley Oop Layup shot              0.000157
# combined_shot_type#Hook Shot                  0.000144
# action_type#Driving Jump shot                 0.000140
# action_type#Alley Oop Dunk Shot               0.000134
# opponent#BKN                                  0.000115
# period#6                                      0.000108
# action_type#Finger Roll Layup Shot            0.000098
# season#2013-14                                0.000087
# action_type#Reverse Dunk Shot                 0.000085
# shot_zone_basic#Right Corner 3                0.000084
# shot_zone_basic#Left Corner 3                 0.000083
# action_type#Other                             0.000068
# action_type#Finger Roll Shot                  0.000056
# action_type#Running Layup Shot                0.000053
# action_type#Running Bank shot                 0.000040
# action_type#Running Hook Shot                 0.000032
# action_type#Fadeaway Bank shot                0.000026
# action_type#Reverse Slam Dunk Shot            0.000024
# action_type#Running Dunk Shot                 0.000014
# action_type#Follow Up Dunk Shot               0.000013
# period#7                                      0.000012
# action_type#Jump Hook Shot                    0.000011
# action_type#Putback Layup Shot                0.000010
# combined_shot_type#Tip Shot                   0.000009
# shot_zone_basic#Backcourt                     0.000002

# %%
#export dataframe for Variance Threshhold features
data_cl_vt = data_cl[ ['shot_made_flag','playoffs', 'home_away', 'action_type#Jump Shot',
       'combined_shot_type#Jump Shot', 'combined_shot_type#Layup',
       'period#1', 'period#2', 'period#3', 'period#4',
       'shot_type#2PT Field Goal', 'shot_type#3PT Field Goal',
       'shot_zone_area#Center(C)', 'shot_zone_area#Left Side Center(LC)',
       'shot_zone_area#Left Side(L)', 'shot_zone_area#Right Side Center(RC)',
       'shot_zone_area#Right Side(R)', 'shot_zone_basic#Above the Break 3',
       'shot_zone_basic#In The Paint (Non-RA)', 'shot_zone_basic#Mid-Range',
       'shot_zone_basic#Restricted Area', 'shot_zone_range#16-24 ft.',
       'shot_zone_range#24+ ft.', 'shot_zone_range#8-16 ft.',
       'shot_zone_range#Less Than 8 ft.', 'game_month#1', 'game_month#2',
       'game_month#3', 'game_month#4', 'game_month#11', 'game_month#12' ] ]

# %%
#export new clean dataframe
data_cl_vt.to_csv('kobe_clean_var_thresh.csv')

# %%
#export feature variana dataframe for RandomForestClassifier
data_cl_rf = data_cl[ ['shot_made_flag','seconds_from_period_end', 'loc_x', 'loc_y', 'shot_distance',
       'action_type#Jump Shot', 'home_away', 'action_type#Layup Shot',
       'period#3', 'period#2', 'period#1', 'period#4',
       'shot_zone_range#Less Than 8 ft.', 'game_month#1', 'game_month#3',
       'game_month#2', 'game_month#12', 'game_month#4', 'game_month#11',
       'playoffs', 'action_type#Running Jump Shot' ] ]

# %%
#export feature variana dataframe for RandomForestClassifier
data_cl_rf.to_csv('kobe_clean_forest.csv')

# %%
#Now we can use tese files to import for other models, without having to run through the munging every time.
